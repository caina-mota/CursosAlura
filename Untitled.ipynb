# %%
ar = [1, 1, 3, 1, 2, 1, 3, 3, 3, 3]
ar.pop()
ar
# Out:
# [1, 1, 3, 1, 2, 1, 3, 3, 3]

# %%
ar = [1]
ar[-1]
# Out:
# 1

# %%
41/20
# Out:
# 2.05

# %% [markdown]
# ![image.png](attachment:fa90ef92-87fa-4ea6-a432-87f0f565cd29.png)
# ![image.png](attachment:2b096034-c0e0-46d3-92fd-e5342819bcd3.png)

# %% [markdown]
# ![image.png](attachment:48f2b705-7814-4db4-b219-6f8950385fd1.png)
# ![image.png](attachment:3b9ebc42-3af1-4013-8745-c8a633d20246.png)
