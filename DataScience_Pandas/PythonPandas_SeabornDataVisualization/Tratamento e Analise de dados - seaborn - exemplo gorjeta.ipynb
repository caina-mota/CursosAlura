# %% [markdown]
# # Importando dados

# %%
import pandas as pd

# %%
pd.read_csv('tips.csv').head(5)
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4

# %%
dados = pd.read_csv('tips.csv')

# %%
dados
# Out:
#      total_bill   tip dessert   day    time  size
# 0         16.99  1.01      No   Sun  Dinner     2
# 1         10.34  1.66      No   Sun  Dinner     3
# 2         21.01  3.50      No   Sun  Dinner     3
# 3         23.68  3.31      No   Sun  Dinner     2
# 4         24.59  3.61      No   Sun  Dinner     4
# ..          ...   ...     ...   ...     ...   ...
# 239       29.03  5.92      No   Sat  Dinner     3
# 240       27.18  2.00     Yes   Sat  Dinner     2
# 241       22.67  2.00     Yes   Sat  Dinner     2
# 242       17.82  1.75      No   Sat  Dinner     2
# 243       18.78  3.00      No  Thur  Dinner     2
#
# [244 rows x 6 columns]

# %% [markdown]
# ## Traduzindo e renomeando os dados

# %%
dados.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renomear = {
    'total_bill' : 'Valor_da_conta', 
    'tip' : 'gorjeta', 
    'dessert' : 'sobremesa', 
    'day' : 'dia', 
    'time' : 'hora_do_dia', 
    'size' : 'total_de_pessoas'
}

# %%
gorjetas = dados.rename(columns = renomear)

# %%
gorjetas
# Out:
#      Valor_da_conta  gorjeta sobremesa   dia hora_do_dia  total_de_pessoas
# 0             16.99     1.01        No   Sun      Dinner                 2
# 1             10.34     1.66        No   Sun      Dinner                 3
# 2             21.01     3.50        No   Sun      Dinner                 3
# 3             23.68     3.31        No   Sun      Dinner                 2
# 4             24.59     3.61        No   Sun      Dinner                 4
# ..              ...      ...       ...   ...         ...               ...
# 239           29.03     5.92        No   Sat      Dinner                 3
# 240           27.18     2.00       Yes   Sat      Dinner                 2
# 241           22.67     2.00       Yes   Sat      Dinner                 2
# 242           17.82     1.75        No   Sat      Dinner                 2
# 243           18.78     3.00        No  Thur      Dinner                 2
#
# [244 rows x 6 columns]

# %%
gorjetas.sobremesa.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {
    'No' : 'Não',
    'Yes' : 'Sim'
}

# %%
gorjetas.sobremesa.map(sim_nao)
# Out:
# 0      Não
# 1      Não
# 2      Não
# 3      Não
# 4      Não
#       ...
# 239    Não
# 240    Sim
# 241    Sim
# 242    Não
# 243    Não
# Name: sobremesa, Length: 244, dtype: object

# %%
gorjetas.sobremesa = gorjetas.sobremesa.map(sim_nao)

# %%
gorjetas.head(3)
# Out:
#    Valor_da_conta  gorjeta sobremesa  dia hora_do_dia  total_de_pessoas
# 0           16.99     1.01       Não  Sun      Dinner                 2
# 1           10.34     1.66       Não  Sun      Dinner                 3
# 2           21.01     3.50       Não  Sun      Dinner                 3

# %%
gorjetas.dia.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dias = {
    'Sun' : 'Dom' , 
    'Sat' : 'Sab', 
    'Thur' : 'Qui', 
    'Fri' : 'Sex'
}

# %%
gorjetas.dia = gorjetas.dia.map(dias)

# %%
gorjetas
# Out:
#      Valor_da_conta  gorjeta sobremesa  dia hora_do_dia  total_de_pessoas
# 0             16.99     1.01       Não  Dom      Dinner                 2
# 1             10.34     1.66       Não  Dom      Dinner                 3
# 2             21.01     3.50       Não  Dom      Dinner                 3
# 3             23.68     3.31       Não  Dom      Dinner                 2
# 4             24.59     3.61       Não  Dom      Dinner                 4
# ..              ...      ...       ...  ...         ...               ...
# 239           29.03     5.92       Não  Sab      Dinner                 3
# 240           27.18     2.00       Sim  Sab      Dinner                 2
# 241           22.67     2.00       Sim  Sab      Dinner                 2
# 242           17.82     1.75       Não  Sab      Dinner                 2
# 243           18.78     3.00       Não  Qui      Dinner                 2
#
# [244 rows x 6 columns]

# %%
gorjetas.dia.unique()
# Out:
# array(['Dom', 'Sab', 'Qui', 'Sex'], dtype=object)

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Dinner', 'Lunch'], dtype=object)

# %%
hora = {
    'Dinner' : 'Jantar',
    'Lunch' : 'Almoço'
}

# %%
gorjetas.hora_do_dia = gorjetas.hora_do_dia.map(hora)

# %%
gorjetas
# Out:
#      Valor_da_conta  gorjeta sobremesa  dia hora_do_dia  total_de_pessoas
# 0             16.99     1.01       Não  Dom      Jantar                 2
# 1             10.34     1.66       Não  Dom      Jantar                 3
# 2             21.01     3.50       Não  Dom      Jantar                 3
# 3             23.68     3.31       Não  Dom      Jantar                 2
# 4             24.59     3.61       Não  Dom      Jantar                 4
# ..              ...      ...       ...  ...         ...               ...
# 239           29.03     5.92       Não  Sab      Jantar                 3
# 240           27.18     2.00       Sim  Sab      Jantar                 2
# 241           22.67     2.00       Sim  Sab      Jantar                 2
# 242           17.82     1.75       Não  Sab      Jantar                 2
# 243           18.78     3.00       Não  Qui      Jantar                 2
#
# [244 rows x 6 columns]

# %% [markdown]
# # Iniciando com o seaborn

# %%
import seaborn as sns

# %%
# !pip show seaborn #demonstra qual versão está sendo utilizada
# Out:
# Name: seaborn
# Version: 0.11.1
# Summary: seaborn: statistical data visualization
# Home-page: https://seaborn.pydata.org
# Author: Michael Waskom
# Author-email: mwaskom@nyu.edu
# License: BSD (3-clause)
# Location: c:\anaconda3\lib\site-packages
# Requires: matplotlib, scipy, pandas, numpy
# Required-by:
# WARNING: Package(s) not found: #demonstra, está, qual, sendo, utilizada, versão

# %% [markdown]
# ## Análise 1 -  Valor da conta e gorjeta

# %%
gorjetas.columns
# Out:
# Index(['Valor_da_conta', 'gorjeta', 'sobremesa', 'dia', 'hora_do_dia',
#        'total_de_pessoas'],
#       dtype='object')

# %%
sns.scatterplot(x= 'Valor_da_conta', y= 'gorjeta', data=gorjetas)
# Out:
# <AxesSubplot:xlabel='Valor_da_conta', ylabel='gorjeta'>

# %%
valor_gorjeta = sns.scatterplot(x= 'Valor_da_conta', y= 'gorjeta', data=gorjetas)

# %% [markdown]
# **Visualmente, o valor da gorjeta aumenta de acordo com o aumento da conta**

# %%
print(f'Quantidade de registros {gorjetas.shape[0]}\n')
print(f'Registros não nulos:\n{gorjetas.count()}')
# Out:
# Quantidade de registros 244
#
# Registros não nulos:
# Valor_da_conta      244
# gorjeta             244
# sobremesa           244
# dia                 244
# hora_do_dia         244
# total_de_pessoas    244
# dtype: int64

# %% [markdown]
# ## Criando o campo percentual

# %%
gorjetas.head(3)
# Out:
#    Valor_da_conta  gorjeta sobremesa  dia hora_do_dia  total_de_pessoas
# 0           16.99     1.01       Não  Dom      Jantar                 2
# 1           10.34     1.66       Não  Dom      Jantar                 3
# 2           21.01     3.50       Não  Dom      Jantar                 3

# %%
gorjetas['percentual'] = gorjetas['gorjeta'] / gorjetas['Valor_da_conta']

# %%
gorjetas.head(3)
# Out:
#    Valor_da_conta  gorjeta sobremesa  dia hora_do_dia  total_de_pessoas  \
# 0           16.99     1.01       Não  Dom      Jantar                 2
# 1           10.34     1.66       Não  Dom      Jantar                 3
# 2           21.01     3.50       Não  Dom      Jantar                 3
#
#    percentual
# 0    0.059447
# 1    0.160542
# 2    0.166587

# %%
gorjetas['percentual'] = gorjetas.percentual.round(2)

# %%
gorjetas.head()
# Out:
#    Valor_da_conta  gorjeta sobremesa  dia hora_do_dia  total_de_pessoas  \
# 0           16.99     1.01       Não  Dom      Jantar                 2
# 1           10.34     1.66       Não  Dom      Jantar                 3
# 2           21.01     3.50       Não  Dom      Jantar                 3
# 3           23.68     3.31       Não  Dom      Jantar                 2
# 4           24.59     3.61       Não  Dom      Jantar                 4
#
#    percentual
# 0        0.06
# 1        0.16
# 2        0.17
# 3        0.14
# 4        0.15

# %%
percentual_conta = sns.scatterplot(x = 'Valor_da_conta', y = 'percentual', data = gorjetas)

# %% [markdown]
# **Visualmente, o valor da conta não é proporcional ao valor da gorjeta**

# %% [markdown]
# ### Gerando outros tipos de gráficos

# %%
percentual_conta_linha = sns.relplot(x='Valor_da_conta', y='percentual', kind = 'line', data = gorjetas)

# %%
sns.lmplot(x='Valor_da_conta', y='percentual', data = gorjetas)

# %% [markdown]
# # Análise 2 -  Sobremesa

# %%
gorjetas[gorjetas.sobremesa == 'Sim']
# Out:
#      Valor_da_conta  gorjeta sobremesa  dia hora_do_dia  total_de_pessoas  \
# 56            38.01     3.00       Sim  Sab      Jantar                 4
# 58            11.24     1.76       Sim  Sab      Jantar                 2
# 60            20.29     3.21       Sim  Sab      Jantar                 2
# 61            13.81     2.00       Sim  Sab      Jantar                 2
# 62            11.02     1.98       Sim  Sab      Jantar                 2
# ..              ...      ...       ...  ...         ...               ...
# 234           15.53     3.00       Sim  Sab      Jantar                 2
# 236           12.60     1.00       Sim  Sab      Jantar                 2
# 237           32.83     1.17       Sim  Sab      Jantar                 2
# 240           27.18     2.00       Sim  Sab      Jantar                 2
# 241           22.67     2.00       Sim  Sab      Jantar                 2
#
#      percentual
# 56         0.08
# 58         0.16
# 60         0.16
# ...

# %%
gorjetas[gorjetas.sobremesa == 'Sim'].describe().round(2)
# Out:
#        Valor_da_conta  gorjeta  total_de_pessoas  percentual
# count           93.00    93.00             93.00       93.00
# mean            20.76     3.01              2.41        0.16
# std              9.83     1.40              0.81        0.09
# min              3.07     1.00              1.00        0.04
# 25%             13.42     2.00              2.00        0.11
# 50%             17.92     3.00              2.00        0.15
# 75%             26.86     3.68              3.00        0.20
# max             50.81    10.00              5.00        0.71

# %%
gorjetas[gorjetas.sobremesa == 'Não'].describe().round(2)
# Out:
#        Valor_da_conta  gorjeta  total_de_pessoas  percentual
# count          151.00   151.00            151.00      151.00
# mean            19.19     2.99              2.67        0.16
# std              8.26     1.38              1.02        0.04
# min              7.25     1.00              1.00        0.06
# 25%             13.32     2.00              2.00        0.14
# 50%             17.59     2.74              2.00        0.16
# 75%             22.76     3.50              3.00        0.18
# max             48.33     9.00              6.00        0.29

# %%
sns.catplot(x='sobremesa', y='gorjeta', data = gorjetas)

# %%
sns.relplot(x='Valor_da_conta', y='gorjeta', hue='sobremesa', data=gorjetas)

# %%
sns.relplot(x='Valor_da_conta', y='gorjeta', hue='sobremesa', col = 'sobremesa', data=gorjetas)

# %%
sns.relplot(x='Valor_da_conta', y='gorjeta', col = 'sobremesa', data=gorjetas)

# %%
sns.lmplot(x='Valor_da_conta', y='gorjeta', col = 'sobremesa', hue = 'sobremesa', data=gorjetas)

# %%
sns.lmplot(x='Valor_da_conta', y='percentual', col = 'sobremesa', hue = 'sobremesa', data=gorjetas)

# %%
sns.relplot(x='Valor_da_conta', y='gorjeta', hue='sobremesa', col = 'sobremesa', kind='line', data=gorjetas)

# %%
sns.relplot(x='Valor_da_conta', y='percentual', hue='sobremesa', col = 'sobremesa', kind='line', data=gorjetas)

# %% [markdown]
# **Visualmente, existe uma diferença no valor da gorjeta daqueles que pediram e que não pediram sobremesa**

# %% [markdown]
# ## Teste de hipótese

# %% [markdown]
# **H<sup>null</sup>**
# > **A distribuição da taxa da gorjeta é a mesma nos dois grupos**
#
# **H<sup>alt</sup>**
# >**A distribuição da taxa de gorjeta não é a mesma nos dois grupos**

# %%
from scipy.stats import ranksums

# %%
sobremesas = gorjetas.query("sobremesa == 'Sim'").percentual

# %%
sem_sobremesas = gorjetas.query("sobremesa == 'Não'").percentual

# %%
sem_sobremesas
# Out:
# 0      0.06
# 1      0.16
# 2      0.17
# 3      0.14
# 4      0.15
#        ...
# 235    0.12
# 238    0.13
# 239    0.20
# 242    0.10
# 243    0.16
# Name: percentual, Length: 151, dtype: float64

# %%
r = ranksums(sobremesas, sem_sobremesas)

# %%
print(f'O valor do p-value é {r.pvalue}')
# Out:
# O valor do p-value é 0.5266635660124415

# %% [markdown]
# Por enquanto, a resposta que nos importará é o **pvalue** de arredondados 0.52, o que significará que, apesar de os dois grupos terem dado gorjetas de valores diferentes entre si, a diferença é **insignificante** do ponto de vista matemático. Ou seja, não poderemos dizer que a população geral será diferente também.
#
# Cientes disso, continuaremos somente com nossa hipótese nula, não aceitando mais a hipótese alternativa. Para aceitarmos esta última, o valor de **pvalue** deveria ser igual ou menor do que 0.05. Como nosso resultado foi maior do que isso, poderemos descartar esta hipótese alternativa.
#
# >O p-value representa a probabilidade daquela amostra ter acontecido dentro da população. Se a chance é pequena, geralmente p-value < 0,05, representa que um evento muito raro aconteceu, então optamos por descartar a hipótese nula, e dizer que ela pode não ser verdade.

# %% [markdown]
# ### Conclusão
# **H<sup>null</sup>**
# > **A distribuição da taxa da gorjeta é a mesma nos dois grupos**

# %% [markdown]
# # Análise 3 - Dia da semana

# %%
gorjetas.head()
# Out:
#    Valor_da_conta  gorjeta sobremesa  dia hora_do_dia  total_de_pessoas  \
# 0           16.99     1.01       Não  Dom      Jantar                 2
# 1           10.34     1.66       Não  Dom      Jantar                 3
# 2           21.01     3.50       Não  Dom      Jantar                 3
# 3           23.68     3.31       Não  Dom      Jantar                 2
# 4           24.59     3.61       Não  Dom      Jantar                 4
#
#    percentual
# 0        0.06
# 1        0.16
# 2        0.17
# 3        0.14
# 4        0.15

# %%
gorjetas.dia.unique()
# Out:
# array(['Dom', 'Sab', 'Qui', 'Sex'], dtype=object)

# %%
sns.catplot(x='dia', y='Valor_da_conta', data = gorjetas)

# %%
sns.relplot(x='Valor_da_conta', y='gorjeta', hue = 'dia', data=gorjetas)

# %%
sns.relplot(x='Valor_da_conta', y='percentual', hue = 'dia', data=gorjetas)

# %%
sns.relplot(x='Valor_da_conta', y='gorjeta', hue='dia',col='dia', data=gorjetas)

# %%
sns.relplot(x='Valor_da_conta', y='percentual', hue='dia',col='dia', data=gorjetas)

# %%
sns.lmplot(x='Valor_da_conta', y='gorjeta', hue='dia',col='dia', data=gorjetas)

# %%
sns.lmplot(x='Valor_da_conta', y='percentual', hue='dia',col='dia', data=gorjetas)

# %% [markdown]
# ### Médias

# %%
media_geral_gorjetas= gorjetas.gorjeta.mean()

# %%
print(f'A média geral das gorjetas é de {media_geral_gorjetas}')
# Out:
# A média geral das gorjetas é de 2.9982786885245902

# %%
gorjetas.groupby(['dia']).mean()
# Out:
#      Valor_da_conta   gorjeta  total_de_pessoas  percentual
# dia
# Dom       21.410000  3.255132          2.842105    0.166974
# Qui       17.682742  2.771452          2.451613    0.161129
# Sab       20.441379  2.993103          2.517241    0.153678
# Sex       17.151579  2.734737          2.105263    0.169474

# %%
gorjetas.groupby(['dia']).mean()[['Valor_da_conta', 'gorjeta', 'percentual']]
# Out:
#      Valor_da_conta   gorjeta  percentual
# dia
# Dom       21.410000  3.255132    0.166974
# Qui       17.682742  2.771452    0.161129
# Sab       20.441379  2.993103    0.153678
# Sex       17.151579  2.734737    0.169474

# %%
print('Frequência dos dias:')
gorjetas.dia.value_counts()
# Out:
# Frequência dos dias:
# Sab    87
# Dom    76
# Qui    62
# Sex    19
# Name: dia, dtype: int64

# %% [markdown]
# ## Teste de Hipóstese

# %% [markdown]
# **H<sup>null</sup>**
# > **A distribuição do valor da conta é igual no sábado e no domingo**
#
# **H<sup>alt</sup>**
# >**A distribuição do valor da conta não é igual no sábado e no domingo**

# %%
valor_conta_domingo = gorjetas.query("dia == 'Dom'").Valor_da_conta

# %%
valor_conta_sabado = gorjetas.query("dia == 'Sab'").Valor_da_conta

# %%
ranksums(valor_conta_domingo, valor_conta_sabado)
# Out:
# RanksumsResult(statistic=0.9198084864360142, pvalue=0.3576728477868443)

# %% [markdown]
# O resultado de pvalue será 0.35, ou seja, apenas aceitaremos a hipótese alternativa se este número for menor do que 0.05; como é maior, apenas nossa hipótese nula é válida. Isso significa que a distribuição do valor da conta é igual no sábado e no domingo.
#
# Portanto, mesmo que o sábado seja mais frequentado e o domingo possua a maior média de gorjetas, não são diferentes no que diz respeito ao valor da conta.

# %%
r2 = ranksums(valor_conta_domingo, valor_conta_sabado)
print(f'O valor do p-value é {r2.pvalue.round(4)}')
# Out:
# O valor do p-value é 0.3577

# %% [markdown]
# Conclusão:
#
# **H<sup>null</sup>**
# > **A distribuição do valor da conta é igual no sábado e no domingo**

# %% [markdown]
# # Análise 4 - Hora do dia

# %%
gorjetas.head()
# Out:
#    Valor_da_conta  gorjeta sobremesa  dia hora_do_dia  total_de_pessoas  \
# 0           16.99     1.01       Não  Dom      Jantar                 2
# 1           10.34     1.66       Não  Dom      Jantar                 3
# 2           21.01     3.50       Não  Dom      Jantar                 3
# 3           23.68     3.31       Não  Dom      Jantar                 2
# 4           24.59     3.61       Não  Dom      Jantar                 4
#
#    percentual
# 0        0.06
# 1        0.16
# 2        0.17
# 3        0.14
# 4        0.15

# %%
gorjetas.hora_do_dia.unique()
# Out:
# array(['Jantar', 'Almoço'], dtype=object)

# %%
sns.catplot(x='hora_do_dia', y='Valor_da_conta', data=gorjetas)

# %%
sns.catplot(x='hora_do_dia', y='Valor_da_conta', kind = 'swarm', data=gorjetas)

# %%
sns.violinplot(x='hora_do_dia', y='Valor_da_conta', data=gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='Valor_da_conta'>

# %%
sns.boxplot(x='hora_do_dia', y='Valor_da_conta', data=gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='Valor_da_conta'>

# %%
almoco = gorjetas.query("hora_do_dia == 'Almoço'").Valor_da_conta

# %%
sns.distplot(almoco)
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Valor_da_conta', ylabel='Density'>

# %%
sns.distplot(almoco, kde = False)
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Valor_da_conta'>

# %%
jantar = gorjetas.query("hora_do_dia == 'Jantar'").Valor_da_conta

# %%
sns.distplot(jantar)
# Out:
# <AxesSubplot:xlabel='Valor_da_conta', ylabel='Density'>

# %%
sns.distplot(jantar, kde = False)
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Valor_da_conta'>

# %% [markdown]
# ## Teste de Hipótese

# %% [markdown]
# **H<sup>null</sup>**
# > **A distribuição do valor da conta é igual no jantar e no almoço**
#
# **H<sup>alt</sup>**
# >**A distribuição do valor da conta não é igual no jantar e no almoço**

# %%
gorjetas.groupby(['hora_do_dia']).mean()[['Valor_da_conta', 'gorjeta', 'percentual']]
# Out:
#              Valor_da_conta   gorjeta  percentual
# hora_do_dia
# Almoço            17.168676  2.728088    0.163971
# Jantar            20.797159  3.102670    0.159773

# %%
ranksums(jantar, almoco)
# Out:
# RanksumsResult(statistic=3.2438872807262955, pvalue=0.0011791039723641672)

# %%
r3 = ranksums(jantar, almoco)
print(f'O valor do p-value é de {r3.pvalue.round(5)}')
# Out:
# O valor do p-value é de 0.00118

# %% [markdown]
# Conclusão:
#
# **H<sup>alt</sup>**
# >**A distribuição do valor da conta não é igual no jantar e no almoço**

# %%
percentual_almoco = gorjetas.query("hora_do_dia == 'Almoço'").percentual

# %%
percentual_jantar = gorjetas.query("hora_do_dia == 'Jantar'").percentual

# %% [markdown]
# **H<sup>null</sup>**
# > **A distribuição da taxa da gorjeta é igual no jantar e no almoço**
#
# **H<sup>alt</sup>**
# >**A distribuição da taxa da gorjeta não é igual no jantar e no almoço**

# %%
r4 = ranksums(percentual_almoco, percentual_jantar)
print(f'O valor do p-value é de {r4.pvalue.round(5)}')
# Out:
# O valor do p-value é de 0.26025

# %% [markdown]
# Conclusão:
#
# **H<sup>null</sup>**
# > **A distribuição da taxa da gorjeta é igual no jantar e no almoço**
